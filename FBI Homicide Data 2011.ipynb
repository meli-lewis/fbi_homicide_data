# %%
import pandas as pd
import re

# %%
df = pd.read_table("homicide2011.DAT", header=None)

# %%
df.applymap(str)
# Out:
#                                                        0
# 0      602AZ001008B811000062058001   0APACHE         ...
# 1      602AZ002008B811000053152002   0COCHISE        ...
# 2      602AZ002008B811000053152002   0COCHISE        ...
# 3      602AZ002008B811000053152002   0COCHISE        ...
# 4      602AZ002055 811000017624002   0DOUGLAS        ...
# 5      602AZ002094 811000044509002   0SIERRA VISTA   ...
# 6      602AZ002094 811000044509002   0SIERRA VISTA   ...
# 7      602AZ003009B8110000548910032751COCONINO       ...
# 8      602AZ003009B8110000548910032751COCONINO       ...
# 9      602AZ003009B8110000548910032751COCONINO       ...
# 10     602AZ003009B8110000548910032751COCONINO       ...
# 11     602AZ004008B811000028307004   0GILA           ...
# 12     602AZ007009A8110003653620076621MARICOPA       ...
# 13     602AZ007009A8110003653620076621MARICOPA       ...
# 14     602AZ007009A8110003653620076621MARICOPA       ...
# ...

# %%
df[0].str.extract('(.{1})(.{2})(.{7})(.{2})(.{1})(.{2})(.{9})(.{3})(.{3})(.{1})(.{24})(.{6})(.{2})(.{6})(.{1})(.{1})(.{3})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{3})(.{3})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})(.{2})(.{1})(.{1})(.{1})(.{2})(.{2})(.{2})(.{1})')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-977107f16b6f> in <module>()
# ...
